# %% [markdown]
# ### Classificação de documentos usando o IMDB dataset
#
#  - Importar o Dataset do IMDB
#
# ### Processo de classificação de texto
#
#  - Preparar o dataset para classificação com dados e labels.
#
# **Primeiro passo** >> Tokenização do texto
#  - Aqui as palavras serão identificadas individualmente, quebrando das sentenças.
#  - Existem técnicas para não apenas quebrar o texto em palavras, mas sim reduzir o tamanho da sentença, separar palavras que não abreviadas juntas, retirar qualquer coisa que não seja parte do texto como HTML markdowns.
#  - Aplicar a Tokenização no texto
